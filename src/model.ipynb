# %% [markdown]
# # Machine Learning - Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sqlalchemy import create_engine
from dotenv import load_dotenv
import pandas as pd
import os

load_dotenv()

DATABASE_URL = os.getenv("DATABASE_URL").replace("postgres://", "postgresql://")

df = pd.read_sql("ml_4geeks_medical_insurance_cost_clean", DATABASE_URL)

# %%
df.head()
# Out:
#    age     bmi  children      charges  sex_num  smoker_num  region_num
# 0   19  27.900         0  16884.92400        1           1           0
# 1   18  33.770         1   1725.55230        0           0           1
# 2   28  33.000         3   4449.46200        0           0           1
# 3   33  22.705         0  21984.47061        0           0           2
# 4   32  28.880         0   3866.85520        0           0           2

# %% [markdown]
# #### Split data

# %%
X = df.drop('charges', axis=1)
y = df['charges']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (1002, 6) (335, 6)

# %% [markdown]
# #### Create Model

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ##### Fitted parameters

# %%
print(f"Intercept (a): {model.intercept_}")
print(f"Coefficients (b1, b2): {model.coef_}")
# Out:
# Intercept (a): -11735.80902630741
# Coefficients (b1, b2): [2.45899692e+02 3.14061094e+02 5.28365682e+02 1.74679413e+01
#  2.30716633e+04 2.03119474e+02]

# %% [markdown]
# #### Model Prediction

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([ 7993.71982593,  5566.17670809, 14240.9920928 , 31750.64176448,
#         9203.73765008, 13353.55834216, 30191.72525637,  1323.13671526,
#        10779.9682047 , 11315.02465132, 10311.3275375 , 33121.58876013,
#        30904.24313553, 17100.22824699, 10518.39528464,  9399.96186443,
#         4074.56658765, 31974.67887212,  3157.5622492 ,  5437.30290064,
#         3766.78832116, 30127.52947275, 14994.72213809, 30342.23692689,
#        31032.84169081,  5470.39734003, 35619.60650146, 36391.03969721,
#        11135.26838888, 13978.62380055,  6270.21566415, 12932.90547095,
#          745.77529047, 11937.31855694, 39724.66154073, 12091.79829094,
#         4577.72875201,  3915.50448673, 31135.53431231,  9133.94357892,
#         6802.01239622, 29888.45341123, 34994.53512151, 12086.97269396,
#         7321.53387558,  3269.62650741,  5967.59264807,  8774.13805246,
#         4246.62938521,  9270.86556828,  6790.71722028, 11859.91333479,
#        31001.05694418,  3852.96054084, 10892.09655427,  9982.1632232 ,
#        10654.85410648,  2434.84136883, 31409.71339792,  9416.17751219,
#        15671.43957841,  8363.66330528, 12496.57171145,  1504.58992482,
#        16692.07083096, 10439.3833494 , 10382.0668943 , 30640.43946583,
#        24707.44075036, 16241.45583383,  7232.99199695,  2775.16163013,
#         7002.42503103,  -135.78615908, 11497.95264306, -1204.71059486,
#        16894.32364949,  8866.41574643,  7548.61079775, 12608.10788704,
#         5665.80355882, 18595.74691103, 15233.65863077, 11187.22578439,
#        36166.41600227, 13359.73811919,  4246.53560052,  2645.84490764,
#         6501.59569847,  4348.83257442, 15204.95182267, 28150.76417243,
#         5422.89533492,  3195.38451957,  2030.11867074, 35688.95000351,
#        14524.10767732,  9030.30341799,  4482.94680593,  8544.2252845 ,
#        13760.48228711, 14957.27625116, 32303.20890106, 14376.60772227,
#        32662.2010617 ,   174.92316293, 30876.46599032, 26684.58067421,
#        13801.15106142,  5910.10151335,  8312.88004132, 11483.11991173,
#         8222.50391163,  9988.08130846,  6079.39739897,  5631.1338757 ,
#         1973.86055011,  3361.161157  ,  7285.30380096,  9229.49249568,
#        36135.87527799,  8057.3224786 , 11768.42780224,  9437.47344809,
#         8963.96861817,  9515.57692486,  4559.57182166, 12138.06296578,
#        30050.11930125, 38685.10607359, 35889.19839898, 11980.3324479 ,
#         2698.7352989 , 11399.37746106, 10198.42234074,  5276.48980842,
#        34811.82724255, 29665.65902908, 25501.7397305 ,  5061.30757165,
